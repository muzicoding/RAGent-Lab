# %% [markdown]
# # 前置准备
# ## 1. 大模型接入
# - **本地部署**
#     - 工具: Ollama
#     - 支持模型: Qwen, DeepSeek等（1.5b、7b、8b、32b...）
# - **云端大模型**
#     - 平台: 阿里云百炼平台等
#     - 模型: Qwen, DeepSeek等（满参数 + 免费额度）

# %%
from pydantic import BaseModel
